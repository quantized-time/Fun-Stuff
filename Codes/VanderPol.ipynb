# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
  return y

def g(y):
  return a*(1-x**2)*y-x

def rkmx(x):
  a=f(x)*t
  b=f(x+0.5*a)*t
  c=f(x+0.5*b)*t
  d=f(x+c)*t
  x=x+(1/6)*(a+2*b+2*c+d)
  return x

def rkmy(x):
  a=g(x)*t
  b=g(x+0.5*a)*t
  c=g(x+0.5*b)*t
  d=g(x+c)*t
  x=x+(1/6)*(a+2*b+2*c+d)
  return x

t=0.01
x=1
y=1
a=0
tpts=[0]
xpts=[x]
ypts=[y]

while a<2:
 for i in range(100,5000):
    x=rkmx(x)
    y=rkmy(y)
    tpts.append(i*t)
    xpts.append(x)
    ypts.append(y)

 xpts=np.array(xpts)
 ypts=np.array(ypts)

 #plt.plot(tpts, xpts, color='green')
 #plt.plot(tpts, ypts, color='red')
 #plt.show()
 plt.plot(xpts, ypts, color='black')


 a+=0.1
 x=1
 y=1
 xpts=[x]
 ypts=[y]
 tpts=[0]

plt.show()
